# %% [markdown]
# #National Health and Nutrition Examination Survey

# %%
#Import libraries
import pandas as pd
import numpy as np

#Read database
df = pd.read_csv('NHANES.csv')
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %% [markdown]
# ## Step 1: Checking For Missing Values

# %%
#checking missing value
# Method 1
df.isnull()

#False - No missing value
#True - Missing value
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     False   False    True   False   False     False     False     False
# 1     False   False    True   False   False     False     False     False
# 2     False   False    True    True   False     False     False     False
# 3     False   False   False   False   False     False     False     False
# 4     False   False   False   False   False     False     False     False
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5730  False   False   False    True   False     False     False     False
# 5731  False   False   False    True   False     False     False     False
# 5732  False   False    True   False   False     False     False     False
# 5733  False    True    True    True   False     False     False     False
# 5734  False   False    True   False   False     False     False     False
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
#Display all headers
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
# 5  83737     2.0     2.0     NaN       2         2        72         1
# 6  83741     1.0     NaN     8.0       1         1        22         4
# 7  83742     1.0     NaN     1.0       2         2        32         1
# 8  83743     NaN     NaN     NaN       2         1        18         5
# 9  83744     1.0     NaN     NaN       2         1        56         4
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# ...

# %% [markdown]
# * SEQN - Respondent sequence number
# * ALQ101 - Had at least 12 alcohol drinks/1 yr?
# * ALQ110 - Had at least 12 alcohol drinks/lifetime?
# * ALQ130 - Avg # alcoholic drinks/day - past 12 mos
# * SMQ020 - Smoked at least 100 cigarettes in life
# * RIAGENDR - Gender
# * RIDAGEYR - Age in years at screening
# * RIDRETH1 - Race/Hispanic origin
# * DMDCITZN - Citizenship status
# * DMDEDUC2 - Education level - Adults 20+
# * DMDMARTL - Marital status
# * DMDHHSIZ - Total number of people in the Household
# * WTINT2YR - Full sample 2 year interview weight
# * SDMVPSU - Masked variance pseudo-PSU
# * SDMVSTRA - Masked variance pseudo-stratum
# * INDFMPIR - Ratio of family income to poverty
# * BPXSY1 - Systolic: Blood pres (1st rdg) mm Hg
# * BPXDI1 - Diastolic: Blood pres (1st rdg) mm Hg
# * BPXSY2 - Systolic: Blood pres (2nd rdg) mm Hg
# * BPXDI2 - Diastolic: Blood pres (2nd rdg) mm Hg
# * BMXHT - Standing Height (cm)
# * BMXBMI - Body Mass Index (kg/m**2)
# * BMXLEG - Upper Leg Length (cm)
# * BMXARML - Upper Arm Length (cm)
# * BMXARMC - Arm Circumference (cm)
# * BMXWAIST - Waist Circumference (cm)
# * HIQ210 - Time when no insurance in past year?

# %%
#Check count of missing value for each columns
df.isnull().sum()
# Out:
# SEQN           0
# ALQ101       527
# ALQ110      4004
# ALQ130      2356
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %% [markdown]
# * 30% Missing data from the overall data will be drop
#   * ALQ130 - Avg # alcoholic drinks/day - past 12 mos
#   * ALQ110 - Had at least 12 alcohol drinks/lifetime?

# %%
#Drop data missing 30% data
df.dropna(subset=['ALQ130'],axis=0, inplace=True)
df.dropna(subset=['ALQ110'],axis=0, inplace=True)

# %%
#Checking number of remaining data left after drop
df.shape
# Out:
# (398, 28)

# %%
df.head()
# Out:
#      SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 3   83735     2.0     1.0     1.0       2         2        56         3
# 4   83736     2.0     1.0     1.0       2         2        42         4
# 13  83754     2.0     1.0     1.0       2         2        67         2
# 27  83785     2.0     1.0     1.0       1         2        60         2
# 30  83788     2.0     1.0     1.0       1         2        69         3
#
#     DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 3        1.0       5.0       6.0         1  102718.00        1       131
# 4        1.0       4.0       3.0         5   17627.67        2       126
# 13       1.0       5.0       1.0         7   10495.87        1       128
# 27       1.0       5.0       3.0         4   10495.87        1       128
# 30       1.0       4.0       1.0         3   50114.53        2       120
#
#     INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
#Rechecking missing values left
df.isnull().sum()
# Out:
# SEQN         0
# ALQ101       0
# ALQ110       0
# ALQ130       0
# SMQ020       0
# RIAGENDR     0
# RIDAGEYR     0
# RIDRETH1     0
# DMDCITZN     0
# DMDEDUC2    25
# DMDMARTL    25
# DMDHHSIZ     0
# WTINT2YR     0
# SDMVPSU      0
# SDMVSTRA     0
# INDFMPIR    44
# BPXSY1      18
# BPXDI1      18
# BPXSY2       8
# BPXDI2       8
# BMXWT        2
# BMXHT        1
# BMXBMI       3
# BMXLEG      15
# BMXARML     10
# BMXARMC      9
# BMXWAIST    12
# HIQ210      63
# dtype: int64

# %%
#Replacing the missing value with mean
df['DMDEDUC2'].replace(np.nan, (df['DMDEDUC2'].mean()), inplace = True)
df['DMDMARTL'].replace(np.nan, (df['DMDMARTL'].mean()), inplace = True)
df['INDFMPIR'].replace(np.nan, (df['INDFMPIR'].mean()), inplace = True)
df['BPXSY1'].replace(np.nan, (df['BPXSY1'].mean()), inplace = True)
df['BPXDI1'].replace(np.nan, (df['BPXDI1'].mean()), inplace = True)
df['BPXSY2'].replace(np.nan, (df['BPXSY2'].mean()), inplace = True)
df['BPXDI2'].replace(np.nan, (df['BPXDI2'].mean()), inplace = True)
df['BMXWT'].replace(np.nan, (df['BMXWT'].mean()), inplace = True)
df['BMXHT'].replace(np.nan, (df['BMXHT'].mean()), inplace = True)
df['BMXBMI'].replace(np.nan, (df['BMXBMI'].mean()), inplace = True)
df['BMXLEG'].replace(np.nan, (df['BMXLEG'].mean()), inplace = True)
df['BMXARML'].replace(np.nan, (df['BMXARML'].mean()), inplace = True)
df['BMXARMC'].replace(np.nan, (df['BMXARMC'].mean()), inplace = True)
df['BMXWAIST'].replace(np.nan, (df['BMXWAIST'].mean()), inplace = True)
df['HIQ210'].replace(np.nan, (df['HIQ210'].mean()), inplace = True)

#Checking total number of missing value in a column AGAIN
df.isnull().sum()
# Out:
# SEQN        0
# ALQ101      0
# ALQ110      0
# ALQ130      0
# SMQ020      0
# RIAGENDR    0
# RIDAGEYR    0
# RIDRETH1    0
# DMDCITZN    0
# DMDEDUC2    0
# DMDMARTL    0
# DMDHHSIZ    0
# WTINT2YR    0
# SDMVPSU     0
# SDMVSTRA    0
# INDFMPIR    0
# BPXSY1      0
# BPXDI1      0
# BPXSY2      0
# BPXDI2      0
# BMXWT       0
# BMXHT       0
# BMXBMI      0
# BMXLEG      0
# BMXARML     0
# BMXARMC     0
# BMXWAIST    0
# HIQ210      0
# dtype: int64

# %% [markdown]
# ## Step 2: Data Normalization

# %%
df.describe(include='all')
# Out:
#                SEQN      ALQ101  ALQ110      ALQ130      SMQ020    RIAGENDR  \
# count    398.000000  398.000000   398.0  398.000000  398.000000  398.000000
# mean   88658.716080    2.035176     1.0    9.010050    1.716080    1.736181
# std     2842.274704    0.495591     0.0   86.394006    0.451466    0.441257
# min    83735.000000    2.000000     1.0    1.000000    1.000000    1.000000
# 25%    86222.750000    2.000000     1.0    1.000000    1.000000    1.000000
# 50%    88817.500000    2.000000     1.0    1.000000    2.000000    2.000000
# 75%    90893.250000    2.000000     1.0    2.000000    2.000000    2.000000
# max    93664.000000    9.000000     1.0  999.000000    2.000000    2.000000
#
#          RIDAGEYR    RIDRETH1    DMDCITZN    DMDEDUC2    DMDMARTL    DMDHHSIZ  \
# count  398.000000  398.000000  398.000000  398.000000  398.000000  398.000000
# mean    48.366834    3.165829    1.185930    3.640751    2.469169    3.298995
# ...

# %% [markdown]
# * WTINT2YR
# * ALQ130
# * BPXSY1
# * BPXDI1
# * BPXSY2
# * BPXDI2
# * BMXWT

# %% [markdown]
# **When to Normalize**
#
# * **Machine Learning Algorithms:** If you are using algorithms sensitive to the scale of the input features (e.g., K-nearest neighbors, neural networks, support vector machines), normalizing BMI can improve performance.
#
# * **Combining with Other Features:** When combining BMI with other features that have different scales, normalization ensures that BMI contributes proportionally to the analysis.
#
# * **Gradient-Based Optimization:** Algorithms that use gradient descent optimization (e.g., logistic regression, neural networks) benefit from normalized data for faster convergence.
#
# **When Not to Normalize**
#
# * **Clinical Interpretation:** If the BMI values are used for clinical interpretation or decision-making (e.g., determining obesity categories), raw values are more meaningful.
#
# * **Threshold-Based Decisions:** If the analysis relies on specific BMI thresholds (e.g., underweight, normal weight, overweight, obesity), normalization might complicate the interpretation.

# %%
#z-score data normalization
df['ALQ130'] = (df['ALQ130']-df['ALQ130'].mean())/df['ALQ130'].std()
df['WTINT2YR'] = (df['WTINT2YR']-df['WTINT2YR'].mean())/df['WTINT2YR'].std()
df['BPXSY1'] = (df['BPXSY1']-df['BPXSY1'].mean())/df['BPXSY1'].std()
df['BPXDI1'] = (df['BPXDI1']-df['BPXDI1'].mean())/df['BPXDI1'].std()
df['BPXSY2'] = (df['BPXSY2']-df['BPXSY2'].mean())/df['BPXSY2'].std()
df['BPXDI2'] = (df['BPXDI2']-df['BPXDI2'].mean())/df['BPXDI2'].std()
df['BMXWT'] = (df['BMXWT']-df['BMXWT'].mean())/df['BMXWT'].std()

#Display
df.describe()
# Out:
#                SEQN      ALQ101  ALQ110        ALQ130      SMQ020    RIAGENDR  \
# count    398.000000  398.000000   398.0  3.980000e+02  398.000000  398.000000
# mean   88658.716080    2.035176     1.0 -5.579010e-17    1.716080    1.736181
# std     2842.274704    0.495591     0.0  1.000000e+00    0.451466    0.441257
# min    83735.000000    2.000000     1.0 -9.271535e-02    1.000000    1.000000
# 25%    86222.750000    2.000000     1.0 -9.271535e-02    1.000000    1.000000
# 50%    88817.500000    2.000000     1.0 -9.271535e-02    2.000000    2.000000
# 75%    90893.250000    2.000000     1.0 -8.114047e-02    2.000000    2.000000
# max    93664.000000    9.000000     1.0  1.145901e+01    2.000000    2.000000
#
#          RIDAGEYR    RIDRETH1    DMDCITZN    DMDEDUC2    DMDMARTL    DMDHHSIZ  \
# count  398.000000  398.000000  398.000000  398.000000  398.000000  398.000000
# mean    48.366834    3.165829    1.185930    3.640751    2.469169    3.298995
# ...

# %% [markdown]
# ## Step 3: Data Binning

# %% [markdown]
# ###**Data Binning For ALQ130**
# * ALQ130 - Avg # alcoholic drinks/day - past 12 mos

# %%
#Creating Bins for 'ALQ130'
ALQ130_bins = np.linspace(df['ALQ130'].min(), df['ALQ130'].max(), num=4)

#Printing the bins
print(ALQ130_bins)
# Out:
# [-0.09271535  3.75786041  7.60843617 11.45901193]

# %%
#Label the bins
ALQ130_groups = ['Light Drinker','Moderate Drinker','Heavy Drinker']

#Assigning Data to the bin
df['ALQ130_bins'] = pd.cut(df['ALQ130'],ALQ130_bins, labels = ALQ130_groups, include_lowest=True)

#Viewing the Binned Data
df[['ALQ130','ALQ130_bins']].head()
# Out:
#         ALQ130    ALQ130_bins
# 5647 -0.092715  Light Drinker
# 5648  0.023033  Light Drinker
# 5653 -0.081140  Light Drinker
# 5702 -0.092715  Light Drinker
# 5714 -0.081140  Light Drinker

# %%
#The count category in the new bin
df['ALQ130_bins'].value_counts()
# Out:
# ALQ130_bins
# Light Drinker       395
# Heavy Drinker         3
# Moderate Drinker      0
# Name: count, dtype: int64

# %% [markdown]
# ###**Data binning for RIDAGEYR**
# * RIDAGEYR - Age in years at screening

# %%
#Creating Bins for 'ALQ130'
RIDAGEYR_bins = np.linspace(df['RIDAGEYR'].min(), df['RIDAGEYR'].max(), num=5)

#Printing the bins
print(RIDAGEYR_bins)
# Out:
# [18.  33.5 49.  64.5 80. ]

# %%
#Label the bins
RIDAGEYR_groups = ['18-33','34-49','50-65','66-80']

#Assigning Data to the bin
# Create a new column 'RIDAGEYR_bins' to store the binned data
df['RIDAGEYR'] = pd.cut(df['RIDAGEYR'],RIDAGEYR_bins, labels = RIDAGEYR_groups, include_lowest=True)

#Viewing the Binned Data
df[['RIDAGEYR','RIDAGEYR_bins']].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-74bd591f6a91> in <cell line: 6>()
#       4 #Assigning Data to the bin
#       5 # Create a new column 'RIDAGEYR_bins' to store the binned data
# ----> 6 df['RIDAGEYR'] = pd.cut(df['RIDAGEYR'],RIDAGEYR_bins, labels = RIDAGEYR_groups, include_lowest=True)
#       7
#       8 #Viewing the Binned Data
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     291             raise ValueError("bins must increase monotonically.")
#     292
# --> 293     fac, bins = _bins_to_cuts(
#     294         x,
#     295         bins,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     425
# ...

# %% [markdown]
# **ERROR ALERT!!!**
#
# * RIDAGEYR is already a category with bins
# * So you don't need to create another bins for it
# * Count value to check the RIDAGEYR categories

# %%
#Recheck RIDAGEYR data type
df.info()

#here we can see it's RIDAGEYR = 'category'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 398 entries, 3 to 5714
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SEQN         398 non-null    int64
#  1   ALQ101       398 non-null    float64
#  2   ALQ110       398 non-null    float64
#  3   ALQ130       398 non-null    float64
#  4   SMQ020       398 non-null    int64
#  5   RIAGENDR     398 non-null    int64
#  6   RIDAGEYR     398 non-null    category
#  7   RIDRETH1     398 non-null    int64
#  8   DMDCITZN     398 non-null    float64
#  9   DMDEDUC2     398 non-null    float64
#  10  DMDMARTL     398 non-null    float64
#  11  DMDHHSIZ     398 non-null    int64
#  12  WTINT2YR     398 non-null    float64
#  13  SDMVPSU      398 non-null    int64
#  14  SDMVSTRA     398 non-null    int64
#  15  INDFMPIR     398 non-null    float64
#  16  BPXSY1       398 non-null    float64
#  17  BPXDI1       398 non-null    float64
# ...

# %%
#Check RIDAGEYR
df.describe(include='all')

#Notice how top category '34-49'
#This means that the column category already have bins
# Out:
#                 SEQN      ALQ101  ALQ110        ALQ130      SMQ020  \
# count     398.000000  398.000000   398.0  3.980000e+02  398.000000
# unique           NaN         NaN     NaN           NaN         NaN
# top              NaN         NaN     NaN           NaN         NaN
# freq             NaN         NaN     NaN           NaN         NaN
# mean    88658.716080    2.035176     1.0 -5.579010e-17    1.716080
# std      2842.274704    0.495591     0.0  1.000000e+00    0.451466
# min     83735.000000    2.000000     1.0 -9.271535e-02    1.000000
# 25%     86222.750000    2.000000     1.0 -9.271535e-02    1.000000
# 50%     88817.500000    2.000000     1.0 -9.271535e-02    2.000000
# 75%     90893.250000    2.000000     1.0 -8.114047e-02    2.000000
# max     93664.000000    9.000000     1.0  1.145901e+01    2.000000
#
#           RIAGENDR RIDAGEYR    RIDRETH1    DMDCITZN    DMDEDUC2    DMDMARTL  \
# count   398.000000      398  398.000000  398.000000  398.000000  398.000000
# ...

# %%
#The count category in RIDAGEYR
df['RIDAGEYR'].value_counts()
# Out:
# RIDAGEYR
# 34-49    121
# 50-65    104
# 18-33     87
# 66-80     86
# Name: count, dtype: int64

# %% [markdown]
# ### **Data Binning for DMDHHSIZ**
# DMDHHSIZ - Total number of people in the Household

# %%
#Creating Bins for 'DMDHHSIZ'
DMDHHSIZ_bins = np.linspace(df['DMDHHSIZ'].min(), df['DMDHHSIZ'].max(), num=4)

#Printing the bins
print(DMDHHSIZ_bins)
# Out:
# [1. 3. 5. 7.]

# %%
#Label the bins
DMDHHSIZ_groups = ['1-3','4-5','6+']

#Assigning Data to the bin
df['DMDHHSIZ_bins'] = pd.cut(df['DMDHHSIZ'],DMDHHSIZ_bins, labels = DMDHHSIZ_groups, include_lowest=True)

#Viewing the Binned Data
df[['DMDHHSIZ','DMDHHSIZ_bins']].head()
# Out:
#     DMDHHSIZ DMDHHSIZ_bins
# 3          1           1-3
# 4          5           4-5
# 13         7            6+
# 27         4           4-5
# 30         3           1-3

# %%
#The count category in the new bin
#Total number of people in the Household
df['DMDHHSIZ_bins'].value_counts()
# Out:
# DMDHHSIZ_bins
# 1-3    236
# 4-5    109
# 6+      53
# Name: count, dtype: int64

# %% [markdown]
# ### **Data Binning for INDFMPIR**
# INDFMPIR - Ratio of family income to poverty

# %%
#Creating Bins for 'INDFMPIR'
INDFMPIR_bins = np.linspace(df['INDFMPIR'].min(), df['INDFMPIR'].max(), num=4)

#Printing the bins
print(INDFMPIR_bins)
# Out:
# [0.         1.66666667 3.33333333 5.        ]

# %%
#Label the bins
INDFMPIR_groups = ['Low Income','Middle Income','High Income']

#Assigning Data to the bin
df['INDFMPIR_bins'] = pd.cut(df['INDFMPIR'],INDFMPIR_bins, labels = INDFMPIR_groups, include_lowest=True)

#Viewing the Binned Data
df[['INDFMPIR','INDFMPIR_bins']].head()
# Out:
#     INDFMPIR  INDFMPIR_bins
# 3       5.00    High Income
# 4       1.23     Low Income
# 13      0.89     Low Income
# 27      5.00    High Income
# 30      1.79  Middle Income

# %%
#The count category in the new bin
#Ratio of family income to poverty
df['INDFMPIR_bins'].value_counts()
# Out:
# INDFMPIR_bins
# Low Income       144
# Middle Income    139
# High Income      115
# Name: count, dtype: int64

# %% [markdown]
# ### **Data Binning For BPXSY1**
# * BPXSY1 - Systolic: Blood pres (1st rdg) mm Hg

# %% [markdown]
# <img src="https://cdn.vertex42.com/ExcelTemplates/Images/blood-pressure-chart-1.gif"/>

# %%
# prompt: how to bin the BPXSY1 which is systolic BP reading,  binning group <90, normal <120, hypertension 120-130, hypertension 140 and  bove

# Define bins and labels
bins = [0, 90, 120, 130, 140, float('inf')]
labels = ['Low', 'Normal', 'Prehypertension', 'Hypertension Stage 1', 'Hypertension Stage 2']

# Bin the data
df['BPXSY1_bins'] = pd.cut(df['BPXSY1'], bins=bins, labels=labels, right=False)

# Display the binned data
print(df[['BPXSY1', 'BPXSY1_bins']].head())
# Out:
#    BPXSY1           BPXSY1_bins
# 0   128.0       Prehypertension
# 1   146.0  Hypertension Stage 2
# 2   138.0  Hypertension Stage 1
# 3   132.0  Hypertension Stage 1
# 4   100.0                Normal

# %%
#The count category in the new bin
#Ratio of family income to poverty
df['BPXSY1_bins'].value_counts()
# Out:
# BPXSY1_bins
# High      2515
# Low          0
# Normal       0
# Name: count, dtype: int64
